# %%
import numpy as np
import pandas as pd

train_data = pd.read_csv('train/train.csv')
test_data = pd.read_csv('test/test.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,5,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_data[0:25]
# Out:
#     service_type  is_mix_service  online_time  1_total_fee 2_total_fee  \
# 0              4               0           85       295.96       296.2
# 1              1               0           10       265.20       261.2
# 2              1               0           12        44.50        70.2
# 3              4               0          134        87.95        81.4
# 4              4               0           84       317.04      314.08
# 5              4               0           46        36.00          36
# 6              1               0           12        33.60        32.7
# 7              3               0           68       200.13        66.5
# 8              4               0          109       116.00         116
# 9              4               0           29        16.00       19.45
# 10             4               0           30        73.95       91.42
# 11             1               0            7        89.00          91
# ...

# %%
test_data[0:25]
# Out:
#     service_type  is_mix_service  online_time  1_total_fee 2_total_fee  \
# 0              4               0          193        80.00          80
# 1              1               0            5        86.70        74.2
# 2              4               0           62        90.90      127.35
# 3              4               0           87        95.45      154.65
# 4              4               0           53        76.00          86
# 5              4               0           70        78.45       184.4
# 6              4               0          105        62.35          61
# 7              1               0           64        66.30        64.3
# 8              4               0           56       169.01       203.3
# 9              1               0           36        97.00       104.2
# 10             4               0           11        80.00         120
# 11             1               0           65        48.50        50.1
# ...

# %%
train_data.current_service.value_counts()
# Out:
# 90063345    201245
# 89950166     93252
# 89950167     51440
# 99999828     37146
# 89016252     36379
# 99104722     36289
# 90109916     26685
# 89950168     23316
# 99999827     22753
# 99999826     20393
# 90155946     15477
# 99999830     14840
# 99999825     14323
# 89016253     10019
# 89016259      9095
# Name: current_service, dtype: int64

# %%
feature = ['service_type', 'is_mix_service', 'online_time', '1_total_fee', '2_total_fee', '3_total_fee',
           '4_total_fee', 'month_traffic', 'many_over_bill', 'contract_type', 'contract_time', 
           'is_promise_low_consume', 'net_service', 'pay_times', 'pay_num', 'last_month_traffic',
           'local_trafffic_month', 'local_caller_time', 'service1_caller_time', 'service2_caller_time',
           'gender', 'age', 'complaint_level', 'former_complaint_num', 'former_complaint_fee']

# %%
train_data.describe()
# Out:
#         service_type  is_mix_service    online_time    1_total_fee  \
# count  612652.000000   612652.000000  612652.000000  612652.000000
# mean        2.748866        0.035844      42.831155      97.411841
# std         1.438612        0.185902      45.367953      89.426252
# min         1.000000        0.000000       1.000000       0.000000
# 25%         1.000000        0.000000      10.000000      46.200000
# 50%         4.000000        0.000000      21.000000      72.630000
# 75%         4.000000        0.000000      64.000000     116.000000
# max         4.000000        1.000000     274.000000    5940.830000
#
#          4_total_fee  month_traffic  many_over_bill  contract_type  \
# count  612652.000000  612652.000000   612652.000000  612652.000000
# mean      102.870227    1159.336403        0.426857       1.491517
# std       101.235433    2754.759625        0.494622       2.967203
# min      -420.270000       0.000000        0.000000       0.000000
# ...

# %%
train_data.current_service = train_data.current_service.replace(90063345, 1)
train_data.current_service = train_data.current_service.replace(89950166, 2)
train_data.current_service = train_data.current_service.replace(89950167, 3)
train_data.current_service = train_data.current_service.replace(99999828, 4)
train_data.current_service = train_data.current_service.replace(89016252, 5)
train_data.current_service = train_data.current_service.replace(99104722, 6)
train_data.current_service = train_data.current_service.replace(90109916, 7)
train_data.current_service = train_data.current_service.replace(89950168, 8)
train_data.current_service = train_data.current_service.replace(99999827, 9)
train_data.current_service = train_data.current_service.replace(99999826, 10)
train_data.current_service = train_data.current_service.replace(90155946, 11)
train_data.current_service = train_data.current_service.replace(99999830, 12)
train_data.current_service = train_data.current_service.replace(99999825, 13)
train_data.current_service = train_data.current_service.replace(89016253, 14)
train_data.current_service = train_data.current_service.replace(89016259, 15)
train_data
# Out:
#         service_type  is_mix_service  online_time  1_total_fee 2_total_fee  \
# 0                  4               0           85       295.96       296.2
# 1                  1               0           10       265.20       261.2
# 2                  1               0           12        44.50        70.2
# 3                  4               0          134        87.95        81.4
# 4                  4               0           84       317.04      314.08
# 5                  4               0           46        36.00          36
# 6                  1               0           12        33.60        32.7
# 7                  3               0           68       200.13        66.5
# 8                  4               0          109       116.00         116
# 9                  4               0           29        16.00       19.45
# 10                 4               0           30        73.95       91.42
# ...

# %%
print train_data.service_type.value_counts()
for i in range(1,5):
    print train_data[train_data.service_type == i].current_service.value_counts()
# Out:
# 4    332956
# 1    243407
# 3     36289
# Name: service_type, dtype: int64
# 1     201245
# 7      26685
# 11     15477
# Name: current_service, dtype: int64
# Series([], Name: current_service, dtype: int64)
# 6    36289
# Name: current_service, dtype: int64
# 2     93252
# 3     51440
# 4     37146
# 5     36379
# 8     23316
# 9     22753
# 10    20393
# 12    14840
# 13    14323
# 14    10019
# 15     9095
# Name: current_service, dtype: int64

# %%
print train_data.is_mix_service.value_counts()
for i in range(0,2):
    print train_data[train_data.is_mix_service == i].current_service.value_counts()
# Out:
# 0    590692
# 1     21960
# Name: is_mix_service, dtype: int64
# 1     201181
# 2      87074
# 3      45942
# 6      36289
# 5      36269
# 4      33727
# 7      26661
# 8      23252
# 9      20006
# 10     18207
# 11     15461
# 12     14835
# 13     12692
# 14     10005
# 15      9091
# Name: current_service, dtype: int64
# 2     6178
# 3     5498
# 4     3419
# 9     2747
# 10    2186
# 13    1631
# 5      110
# 8       64
# 1       64
# 7       24
# 11      16
# 14      14
# 12       5
# 15       4
# Name: current_service, dtype: int64

# %%
print train_data.many_over_bill.value_counts()
for i in range(0,2):
    print train_data[train_data.many_over_bill == i].current_service.value_counts()
# Out:
# 0    351137
# 1    261515
# Name: many_over_bill, dtype: int64
# 2     81670
# 3     44235
# 6     32190
# 4     31320
# 5     29319
# 7     21594
# 8     21541
# 9     19262
# 10    17630
# 13    12806
# 1     12581
# 12    11714
# 14     7616
# 15     6763
# 11      896
# Name: current_service, dtype: int64
# 1     188664
# 11     14581
# 2      11582
# 3       7205
# 5       7060
# 4       5826
# 7       5091
# 6       4099
# 9       3491
# 12      3126
# 10      2763
# 14      2403
# 15      2332
# 8       1775
# 13      1517
# Name: current_service, dtype: int64

# %%
print train_data.contract_type.value_counts()
for i in range(0,13):
    print train_data[train_data.contract_type == i].current_service.value_counts()
# Out:
# 0     386469
# 1      89531
# 3      74188
# 9      38379
# 12     18585
# 7       2909
# 6       1911
# 2        669
# 8         11
# Name: contract_type, dtype: int64
# 1     201240
# 6      36289
# 5      33684
# 7      26683
# 2      17477
# 11     15476
# 14      9464
# 15      8819
# 12      8538
# 8       7448
# 4       6245
# 3       5449
# 9       4271
# 10      3326
# 13      2060
# Name: current_service, dtype: int64
# 3     25624
# 4     14800
# 2     12917
# 10    10671
# 13    10583
# 9      9352
# 12     4510
# 8      1074
# Name: current_service, dtype: int64
# 4     159
# 10    158
# 3     119
# 9      82
# 2      80
# 13     36
# 8      35
# Name: current_service, dtype: int64
# 2     34466
# 8     11176
# 3      8630
# 4      8148
# 9      4725
# 5      2666
# 10     2375
# 12      680
# 14      545
# 13      536
# 15      238
# 1         3
# Name: current_service, dtype: int64
# Series([], Name: current_service, dtype: int64)
# ...

# %%
print train_data.is_promise_low_consume.value_counts()
for i in range(0,2):
    print train_data[train_data.is_promise_low_consume == i].current_service.value_counts()
# Out:
# 0    571663
# 1     40989
# Name: is_promise_low_consume, dtype: int64
# 1     201227
# 2      82015
# 3      44005
# 5      35110
# 6      34227
# 4      30935
# 7      26675
# 8      21547
# 9      19361
# 10     17707
# 11     15477
# 12     13030
# 13     12903
# 14      9263
# 15      8181
# Name: current_service, dtype: int64
# 2     11237
# 3      7435
# 4      6211
# 9      3392
# 10     2686
# 6      2062
# 12     1810
# 8      1769
# 13     1420
# 5      1269
# 15      914
# 14      756
# 1        18
# 7        10
# Name: current_service, dtype: int64
