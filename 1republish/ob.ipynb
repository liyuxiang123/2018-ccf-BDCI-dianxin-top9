# %%
import numpy as np
import pandas as pd

train_data = pd.read_csv('train/train_all.csv')
test_data = pd.read_csv('test/republish_test.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,5,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_data[:25]
# Out:
#     service_type  is_mix_service  online_time  1_total_fee 2_total_fee  \
# 0              4               0           85       295.96       296.2
# 1              1               0           10       265.20       261.2
# 2              1               0           12        44.50        70.2
# 3              4               0          134        87.95        81.4
# 4              4               0           84       317.04      314.08
# 5              4               0           46        36.00          36
# 6              1               0           12        33.60        32.7
# 7              4               0          109       116.00         116
# 8              4               0           30        73.95       91.42
# 9              1               0            7        89.00          91
# 10             4               0           47        42.00          42
# 11             4               0           51        76.10         156
# ...

# %%
train_data.current_service.value_counts()
# Out:
# 90063345    287219
# 89950166    133224
# 89950167     73842
# 99999828     52939
# 90109916     38096
# 89950168     33462
# 99999827     32531
# 99999826     29054
# 90155946     22037
# 99999830     21236
# 99999825     20350
# Name: current_service, dtype: int64

# %%
train_data.describe()
# Out:
#         service_type  is_mix_service    online_time    1_total_fee  \
# count  743990.000000   743990.000000  743990.000000  743990.000000
# mean        2.599368        0.041987      42.163250     105.316648
# std         1.496706        0.200560      45.526346      90.661524
# min         1.000000        0.000000       1.000000       0.000000
# 25%         1.000000        0.000000      10.000000      52.200000
# 50%         4.000000        0.000000      17.000000      76.000000
# 75%         4.000000        0.000000      65.000000     127.450000
# max         4.000000        1.000000     274.000000    5940.830000
#
#          4_total_fee  month_traffic  many_over_bill  contract_type  \
# count  743990.000000  743990.000000   743990.000000  743990.000000
# mean      110.909542    1280.314131        0.471436       1.733792
# std       102.790653    2865.051949        0.499184       3.145238
# min      -420.270000       0.000000        0.000000       0.000000
# ...

# %%
test_data.describe()
# Out:
#         service_type  is_mix_service    online_time    1_total_fee  \
# count  200000.000000   200000.000000  200000.000000  200000.000000
# mean        2.007635        0.076200      30.878480      85.655853
# std         1.416826        0.265319      34.261823      67.284647
# min         1.000000        0.000000       4.000000       0.000000
# 25%         1.000000        0.000000       9.000000      49.400000
# 50%         1.000000        0.000000      15.000000      68.600000
# 75%         4.000000        0.000000      47.000000      99.200000
# max         4.000000        1.000000     272.000000    2481.600000
#
#          4_total_fee  month_traffic  many_over_bill  contract_type  \
# count  200000.000000  200000.000000   200000.000000  200000.000000
# mean       88.896016     849.698772        0.623640       1.038890
# std        82.338231    2486.963633        0.484473       2.734195
# min        -9.200000       0.000000        0.000000       0.000000
# ...

# %%
train_data.current_service = train_data.current_service.replace(90063345, 1)
train_data.current_service = train_data.current_service.replace(90109916, 2)
train_data.current_service = train_data.current_service.replace(90155946, 3)
train_data.current_service = train_data.current_service.replace(89950166, 4)
train_data.current_service = train_data.current_service.replace(89950167, 5)
train_data.current_service = train_data.current_service.replace(99999828, 6)
train_data.current_service = train_data.current_service.replace(89950168, 7)
train_data.current_service = train_data.current_service.replace(99999827, 8)
train_data.current_service = train_data.current_service.replace(99999826, 9)
train_data.current_service = train_data.current_service.replace(99999830, 10)
train_data.current_service = train_data.current_service.replace(99999825, 11)

# %%
print test_data.service_type.value_counts()
for i in range(1,5):
    print test_data[train_data.service_type == i].current_service.value_counts()
# Out:
# 1    132818
# 4     67163
# 3        19
# Name: service_type, dtype: int64
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# AttributeErrorTraceback (most recent call last)
# <ipython-input-7-be6b087f3286> in <module>()
#       1 print test_data.service_type.value_counts()
#       2 for i in range(1,5):
# ----> 3     print test_data[train_data.service_type == i].current_service.value_counts()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'current_service'

# %%
print train_data.service_type.value_counts()
for i in range(1,5):
    print train_data[train_data.service_type == i].current_service.value_counts()
# Out:
# 4    396638
# 1    347352
# Name: service_type, dtype: int64
# 1    287219
# 2     38096
# 3     22037
# Name: current_service, dtype: int64
# Series([], Name: current_service, dtype: int64)
# Series([], Name: current_service, dtype: int64)
# 4     133224
# 5      73842
# 6      52939
# 7      33462
# 8      32531
# 9      29054
# 10     21236
# 11     20350
# Name: current_service, dtype: int64

# %%
print train_data.is_mix_service.value_counts()
for i in range(0,2):
    print train_data[train_data.is_mix_service == i].current_service.value_counts()
# Out:
# 0    712752
# 1     31238
# Name: is_mix_service, dtype: int64
# 1     287138
# 4     124388
# 5      65951
# 6      48074
# 2      38063
# 7      33361
# 8      28620
# 9      25908
# 3      22017
# 10     21230
# 11     18002
# Name: current_service, dtype: int64
# 4     8836
# 5     7891
# 6     4865
# 8     3911
# 9     3146
# 11    2348
# 7      101
# 1       81
# 2       33
# 3       20
# 10       6
# Name: current_service, dtype: int64

# %%
print train_data.many_over_bill.value_counts()
for i in range(0,2):
    print train_data[train_data.many_over_bill == i].current_service.value_counts()
# Out:
# 0    393246
# 1    350744
# Name: many_over_bill, dtype: int64
# 4     116634
# 5      63478
# 6      44638
# 2      30921
# 7      30893
# 8      27544
# 9      25124
# 11     18217
# 1      17813
# 10     16728
# 3       1256
# Name: current_service, dtype: int64
# 1     269406
# 3      20781
# 4      16590
# 5      10364
# 6       8301
# 2       7175
# 8       4987
# 10      4508
# 9       3930
# 7       2569
# 11      2133
# Name: current_service, dtype: int64

# %%
print train_data.contract_type.value_counts()
for i in range(0,13):
    print train_data[train_data.contract_type == i].current_service.value_counts()
# Out:
# 0     425806
# 1     127830
# 3     101240
# 9      54837
# 12     26455
# 7       4141
# 6       2734
# 2        931
# 8         16
# Name: contract_type, dtype: int64
# 1     287212
# 2      38093
# 4      25008
# 3      22036
# 10     12293
# 7      10665
# 6       8914
# 5       7813
# 8       6081
# 9       4760
# 11      2931
# Name: current_service, dtype: int64
# 5     36684
# 6     21022
# 4     18518
# 9     15168
# 11    15086
# 8     13408
# 10     6425
# 7      1519
# Name: current_service, dtype: int64
# 9     222
# 6     213
# 5     168
# 8     115
# 4     110
# 7      54
# 11     49
# Name: current_service, dtype: int64
# 4     49240
# 7     16012
# 5     12481
# 6     11604
# 8      6794
# 9      3372
# 10      965
# 11      766
# 1         5
# 2         1
# Name: current_service, dtype: int64
# Series([], Name: current_service, dtype: int64)
# Series([], Name: current_service, dtype: int64)
# 4     1272
# 7      514
# 6      500
# 5      180
# 8      173
# ...

# %%
print train_data.is_promise_low_consume.value_counts()
for i in range(0,2):
    print train_data[train_data.is_promise_low_consume == i].current_service.value_counts()
# Out:
# 0    692457
# 1     51533
# Name: is_promise_low_consume, dtype: int64
# 1     287197
# 4     117087
# 5      63141
# 6      44067
# 2      38083
# 7      30922
# 8      27617
# 9      25330
# 3      22037
# 10     18645
# 11     18331
# Name: current_service, dtype: int64
# 4     16137
# 5     10701
# 6      8872
# 8      4914
# 9      3724
# 10     2591
# 7      2540
# 11     2019
# 1        22
# 2        13
# Name: current_service, dtype: int64

# %%
print train_data.gender.value_counts()
for i in range(0,2):
    print train_data[train_data.gender == i].current_service.value_counts()
# Out:
# 1     460291
# 2     197236
# 1      41013
# 0      20927
# 2      17220
# 01      3671
# 0       1830
# 02      1647
# 00       153
# \N         2
# Name: gender, dtype: int64
# 6     5390
# 4     3323
# 5     2794
# 9     2766
# 11    2303
# 8     2154
# 7     1268
# 10     909
# 1       17
# 3        2
# 2        1
# Name: current_service, dtype: int64
# 1     192633
# 4      74949
# 5      43701
# 6      31060
# 2      24993
# 8      19115
# 7      17010
# 3      16695
# 9      16527
# 11     11925
# 10     11683
# Name: current_service, dtype: int64

# %%
train_data.loc[train_data.current_service == 90063345].describe()
# Out:
#        service_type  is_mix_service    online_time    1_total_fee  \
# count      287219.0   287219.000000  287219.000000  287219.000000
# mean            1.0        0.000282      10.365310      56.066720
# std             0.0        0.016791       6.752563      25.157014
# min             1.0        0.000000       2.000000       0.000000
# 25%             1.0        0.000000       7.000000      41.700000
# 50%             1.0        0.000000      10.000000      52.700000
# 75%             1.0        0.000000      13.000000      67.500000
# max             1.0        1.000000     235.000000     582.390000
#
#          4_total_fee  month_traffic  many_over_bill  contract_type  \
# count  287219.000000  287219.000000   287219.000000  287219.000000
# mean       55.008001      84.803677        0.937981       0.000115
# std        33.324025     602.571316        0.241190       0.026846
# min        -1.800000       0.000000        0.000000       0.000000
# ...

# %%
train_data.loc[train_data.current_service == 90109916].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       38096.0    38096.000000  38096.000000  38096.000000  38096.000000
# mean            1.0        0.000866     13.486455     49.498514     56.292003
# std             0.0        0.029419     11.704384     25.305064     41.978883
# min             1.0        0.000000      4.000000      0.000000     -0.080000
# 25%             1.0        0.000000      9.000000     36.000000     36.200000
# 50%             1.0        0.000000     12.000000     39.000000     44.900000
# 75%             1.0        0.000000     15.000000     56.400000     65.900000
# max             1.0        1.000000    250.000000    676.600000   1230.600000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   38096.000000    38096.000000   38096.000000   38096.000000
# mean     3093.696489        0.188340       0.000551       0.000630
# ...

# %%
train_data.loc[train_data.current_service == 90155946].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       22037.0    22037.000000  22037.000000  22037.000000  22037.000000
# mean            1.0        0.000908     11.073967     93.024918     96.500001
# std             0.0        0.030113      9.873674     27.385611     41.332537
# min             1.0        0.000000      4.000000      0.000000     -0.090000
# 25%             1.0        0.000000      7.000000     80.200000     82.500000
# 50%             1.0        0.000000     10.000000     88.700000     91.400000
# 75%             1.0        0.000000     12.000000     98.300000    108.400000
# max             1.0        1.000000    189.000000    636.500000    675.580000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   22037.000000    22037.000000   22037.000000   22037.000000
# mean      115.375528        0.943005       0.000408       0.000272
# ...

# %%
train_data.loc[train_data.current_service == 89950166].describe()
# Out:
#        service_type  is_mix_service    online_time    1_total_fee  \
# count      133224.0   133224.000000  133224.000000  133224.000000
# mean            4.0        0.066324      67.674233      97.434988
# std             0.0        0.248849      48.390461      55.687431
# min             4.0        0.000000       2.000000       0.000000
# 25%             4.0        0.000000      33.000000      72.000000
# 50%             4.0        0.000000      58.000000      79.450000
# 75%             4.0        0.000000      88.000000     106.530000
# max             4.0        1.000000     274.000000    1745.100000
#
#          4_total_fee  month_traffic  many_over_bill  contract_type  \
# count  133224.000000  133224.000000   133224.000000  133224.000000
# mean      103.634584    1701.711557        0.124527       4.128130
# std        66.048604    3329.134965        0.330183       3.808463
# min       -28.200000       0.000000        0.000000       0.000000
# ...

# %%
train_data.loc[train_data.current_service == 89950167].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       73842.0    73842.000000  73842.000000  73842.000000  73842.000000
# mean            4.0        0.106863     68.607852    138.373387    149.435433
# std             0.0        0.308941     47.766860     70.447411     81.745807
# min             4.0        0.000000      4.000000      0.000000    -65.350000
# 25%             4.0        0.000000     31.000000    106.000000    106.000000
# 50%             4.0        0.000000     62.000000    115.670000    122.930000
# 75%             4.0        0.000000     89.000000    155.167500    169.800000
# max             4.0        1.000000    274.000000   5940.830000   5141.270000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   73842.000000    73842.000000   73842.000000   73842.000000
# mean     1963.255674        0.140354       3.295591      17.169957
# ...

# %%
train_data.loc[train_data.current_service == 99999828].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       52939.0    52939.000000  52939.000000  52939.000000  52939.000000
# mean            4.0        0.091898     76.025331    170.073363    184.070930
# std             0.0        0.288885     46.054377     86.102167     99.031814
# min             4.0        0.000000      4.000000      0.000000   -420.270000
# 25%             4.0        0.000000     45.000000    135.950000    136.000000
# 50%             4.0        0.000000     68.000000    144.300000    155.050000
# 75%             4.0        0.000000     92.000000    196.000000    211.000000
# max             4.0        1.000000    274.000000   2838.660000   2809.660000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   52939.000000    52939.000000   52939.000000   52939.000000
# mean     2081.903662        0.156803       3.040273      14.956252
# ...

# %%
train_data.loc[train_data.current_service == 89950168].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       33462.0    33462.000000  33462.000000  33462.000000  33462.000000
# mean            4.0        0.003018     63.136334     71.745083     75.473471
# std             0.0        0.054857     57.477900     61.159336     69.864731
# min             4.0        0.000000      1.000000      0.000000    -17.700000
# 25%             4.0        0.000000     15.000000     38.250000     36.600000
# 50%             4.0        0.000000     45.000000     56.100000     56.000000
# 75%             4.0        0.000000     93.000000     76.000000     79.950000
# max             4.0        1.000000    274.000000   1360.600000   1437.340000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   33462.000000    33462.000000   33462.000000   33462.000000
# mean      913.764870        0.076774       2.858855       8.771024
# ...

# %%
train_data.loc[train_data.current_service == 99999827].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       32531.0    32531.000000  32531.000000  32531.000000  32531.000000
# mean            4.0        0.120224     72.374935    212.595623    227.191278
# std             0.0        0.325228     41.417180    100.779949    117.890969
# min             4.0        0.000000      4.000000      0.000000     -5.850000
# 25%             4.0        0.000000     45.000000    166.000000    166.100000
# 50%             4.0        0.000000     69.000000    180.350000    191.480000
# 75%             4.0        0.000000     88.000000    236.000000    255.300000
# max             4.0        1.000000    274.000000   2506.100000   4469.100000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   32531.000000    32531.000000   32531.000000   32531.000000
# mean     2966.567606        0.153300       2.891427      15.927239
# ...

# %%
train_data.loc[train_data.current_service == 99999826].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       29054.0    29054.000000  29054.000000  29054.000000  29054.000000
# mean            4.0        0.108281     70.082846    249.325789    265.450868
# std             0.0        0.310740     39.022442    124.443021    140.416746
# min             4.0        0.000000      4.000000      0.000000     -0.090000
# 25%             4.0        0.000000     47.000000    196.000000    196.100000
# 50%             4.0        0.000000     68.000000    211.100000    222.400000
# 75%             4.0        0.000000     86.000000    275.000000    297.300000
# max             4.0        1.000000    274.000000   3046.000000   4049.160000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   29054.000000    29054.000000   29054.000000   29054.000000
# mean     3538.421357        0.135265       2.886109      19.616094
# ...

# %%
train_data.loc[train_data.current_service == 99999830].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       21236.0    21236.000000  21236.000000  21236.000000  21236.000000
# mean            4.0        0.000283     71.316962    120.653684    130.342202
# std             0.0        0.016807     43.469248     76.146876     86.351022
# min             4.0        0.000000     24.000000      0.000000     -0.080000
# 25%             4.0        0.000000     36.000000     76.047500     76.900000
# 50%             4.0        0.000000     60.000000     92.000000    100.600000
# 75%             4.0        0.000000     91.000000    140.000000    149.687500
# max             4.0        1.000000    274.000000   1464.400000   1795.000000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   21236.000000    21236.000000   21236.000000   21236.000000
# mean     1286.873795        0.212281       1.286448      13.000848
# ...

# %%
train_data.loc[train_data.current_service == 99999825].describe()
# Out:
#        service_type  is_mix_service   online_time   1_total_fee   4_total_fee  \
# count       20350.0    20350.000000  20350.000000  20350.000000  20350.000000
# mean            4.0        0.115381     74.184570    343.521604    366.722885
# std             0.0        0.319489     38.442225    138.065129    166.703640
# min             4.0        0.000000      4.000000      0.000000      0.000000
# 25%             4.0        0.000000     54.000000    296.000000    296.100000
# 50%             4.0        0.000000     74.000000    303.830000    314.100000
# 75%             4.0        0.000000     88.000000    365.000000    396.000000
# max             4.0        1.000000    274.000000   3857.690000   4823.910000
#
#        month_traffic  many_over_bill  contract_type  contract_time  \
# count   20350.000000    20350.000000   20350.000000   20350.000000
# mean     3374.697330        0.104816       1.705012      22.736265
# ...
